# %% [markdown]
# <a href="https://colab.research.google.com/github/deboralima98025-gif/Aula4git/blob/main/programanomenascimento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("=== Cadastro de Usuário ===")

nome = input("Digite seu nome completo: ")

while True:
    try:
        ano_nascimento = int(input("Digite seu ano de nascimento (1922 a 2021): "))

        if 1922 <= ano_nascimento <= 2021:
            idade = 2022 - ano_nascimento
            print("\nNome:", nome)
            print("Idade em 2022:", idade, "anos")
            break
        else:
            print("Erro: ano fora do intervalo permitido.")

    except ValueError:
        print("Erro: digite um número válido para o ano.")
# Out:
# === Cadastro de Usuário ===
